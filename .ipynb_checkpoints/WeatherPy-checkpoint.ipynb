# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 643

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# lat, lng, max temp, humidity, cloudiness, wind speed, country, date
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = url + "appid=" + weather_api_key + "&q="

lat = []
lon = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
cities_with_data = []
cities_not_found = []
#test = ['atlanta']
record = 1
set_count = 1


print("Beginning Data Retrieval")
print("------------------------------")
for city in cities:
    weather_response = requests.get(query_url + city).json()
    print(f"Processing Record {record} of Set {set_count} | {city}")
    if record < 50:
        try:
            cities_with_data.append(weather_response['name'])
            lat.append(weather_response['coord']['lat'])
            lon.append(weather_response['coord']['lon'])
            max_temp.append(weather_response['main']['temp_max'])
            humidity.append(weather_response['main']['humidity'])
            cloudiness.append(weather_response['clouds']['all'])
            wind_speed.append(weather_response['wind']['speed'])
            country.append(weather_response['sys']['country'])
            date.append(weather_response['dt'])
        except:
            print(f"City '{city}' not found. Skipping...")
            cities_not_found.append(city)

        record+=1
    else:
        time.sleep(5)
        record = 1
        set_count+=1

print("------------------------------")
print(f"Data Retrieval Complete.\nProcessed {len(cities_with_data)} number of cities.\n{len(cities_not_found)} cities not found.")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | belushya guba
# City 'belushya guba' not found. Skipping...
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | palabuhanratu
# City 'palabuhanratu' not found. Skipping...
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | porto novo
# Processing Record 7 of Set 1 | dikson
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | luderitz
# Processing Record 14 of Set 1 | havre-saint-pierre
# Processing Record 15 of Set 1 | san cristobal
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | qaqortoq
# Processing Record 19 of Set 1 | virginia beach
# Processing Record 20 of Set 1 | simpang
# Processing Record 21 of Set 1 | chokurdakh
# Processing Record 22 of Set 1 | koppies
# Processing Record 23 of Set 1 | ponta grossa
# Processing Record 24 of Set 1 | labuhan
# Processing Record 25 of Set 1 | vaitape
# Processing Record 26 of Set 1 | meulaboh
# Processing Record 27 of Set 1 | kalmar
# Processing Record 28 of Set 1 | jumla
# Processing Record 29 of Set 1 | kilindoni
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | andradas
# Processing Record 34 of Set 1 | fort saint james
# Processing Record 35 of Set 1 | tambilil
# Processing Record 36 of Set 1 | illoqqortoormiut
# City 'illoqqortoormiut' not found. Skipping...
# Processing Record 37 of Set 1 | upernavik
# Processing Record 38 of Set 1 | kamyzyak
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | atherton
# Processing Record 41 of Set 1 | tromso
# Processing Record 42 of Set 1 | roswell
# Processing Record 43 of Set 1 | polunochnoye
# Processing Record 44 of Set 1 | kaitangata
# Processing Record 45 of Set 1 | esperance
# Processing Record 46 of Set 1 | kruisfontein
# Processing Record 47 of Set 1 | grand gaube
# Processing Record 48 of Set 1 | samarai
# Processing Record 49 of Set 1 | ostrovnoy
# Processing Record 50 of Set 1 | flinders
# Processing Record 51 of Set 1 | acapulco
# Processing Record 1 of Set 2 | barentsburg
# City 'barentsburg' not found. Skipping...
# Processing Record 2 of Set 2 | bonavista
# Processing Record 3 of Set 2 | mayumba
# Processing Record 41 of Set 4 | avarua
# Processing Record 42 of Set 4 | hemnesberget
# Processing Record 43 of Set 4 | shenjiamen
# Processing Record 44 of Set 4 | masindi
# Processing Record 45 of Set 4 | cabo san lucas
# Processing Record 46 of Set 4 | cape canaveral
# Processing Record 47 of Set 4 | saint anthony
# Processing Record 48 of Set 4 | isangel
# Processing Record 49 of Set 4 | saint george
# Processing Record 50 of Set 4 | karakulino
# Processing Record 51 of Set 4 | attawapiskat
# Processing Record 1 of Set 5 | hadgaon
# Processing Record 2 of Set 5 | atasu
# Processing Record 3 of Set 5 | skibbereen
# Processing Record 4 of Set 5 | aklavik
# Processing Record 5 of Set 5 | fortuna
# Processing Record 6 of Set 5 | mehamn
# Processing Record 7 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 5 | mersing
# Processing Record 9 of Set 5 | mundargi
# Processing Record 10 of Set 5 | takoradi
# Processing Record 11 of Set 5 | hamilton
# Processing Record 12 of Set 5 | nicolas bravo
# Processing Record 13 of Set 5 | nioro
# Processing Record 14 of Set 5 | lincoln
# Processing Record 15 of Set 5 | krasnoselkup
# Processing Record 16 of Set 5 | saint-augustin
# Processing Record 17 of Set 5 | port blair
# Processing Record 18 of Set 5 | mys shmidta
# City 'mys shmidta' not found. Skipping...
# Processing Record 19 of Set 5 | batangafo
# Processing Record 20 of Set 5 | durazno
# Processing Record 21 of Set 5 | kemijarvi
# Processing Record 22 of Set 5 | samana
# Processing Record 23 of Set 5 | lebu
# Processing Record 24 of Set 5 | grindavik
# Processing Record 25 of Set 5 | ixtapa
# Processing Record 26 of Set 5 | salalah
# Processing Record 27 of Set 5 | andenes
# Processing Record 28 of Set 5 | souillac
# Processing Record 29 of Set 5 | grand centre
# City 'grand centre' not found. Skipping...
# Processing Record 30 of Set 5 | kaduna
# Processing Record 31 of Set 5 | port elizabeth
# Processing Record 32 of Set 5 | zolotukhino
# Processing Record 33 of Set 5 | jardim
# Processing Record 34 of Set 5 | samusu
# City 'samusu' not found. Skipping...
# Processing Record 35 of Set 5 | bull savanna
# Processing Record 36 of Set 5 | perth
# Processing Record 37 of Set 5 | saint-denis
# Processing Record 38 of Set 5 | jatai
# Processing Record 39 of Set 5 | subiaco
# Processing Record 40 of Set 5 | somerset
# Processing Record 41 of Set 5 | sunrise manor
# Processing Record 42 of Set 5 | tanout
# Processing Record 43 of Set 5 | batemans bay
# Processing Record 44 of Set 5 | qaanaaq
# Processing Record 45 of Set 5 | tsienyane
# City 'tsienyane' not found. Skipping...
# Processing Record 46 of Set 5 | ekhabi
# Processing Record 47 of Set 5 | labutta
# City 'labutta' not found. Skipping...
# Processing Record 48 of Set 5 | helong
# Processing Record 49 of Set 5 | lompoc
# Processing Record 50 of Set 5 | cherskiy
# Processing Record 51 of Set 5 | gigmoto
# Processing Record 1 of Set 6 | san carlos de bariloche
# Processing Record 2 of Set 6 | meaford
# Processing Record 3 of Set 6 | kupang
# Processing Record 4 of Set 6 | visby
# Processing Record 5 of Set 6 | tabiauea
# City 'tabiauea' not found. Skipping...
# Processing Record 6 of Set 6 | pingliang
# Processing Record 7 of Set 6 | uwajima
# Processing Record 8 of Set 6 | bandarbeyla
# Processing Record 9 of Set 6 | mountain home
# Processing Record 10 of Set 6 | thompson
# Processing Record 11 of Set 6 | souris
# Processing Record 12 of Set 6 | bathsheba
# Processing Record 13 of Set 6 | najran
# Processing Record 14 of Set 6 | pechora
# Processing Record 15 of Set 6 | codrington
# Processing Record 16 of Set 6 | kenai
# Processing Record 17 of Set 6 | wolfville
# Processing Record 18 of Set 6 | kousseri
# Processing Record 19 of Set 6 | sao gabriel da cachoeira
# Processing Record 20 of Set 6 | lazaro cardenas
# Processing Record 21 of Set 6 | dongsheng
# Processing Record 22 of Set 6 | awbari
# Processing Record 23 of Set 6 | tasiilaq
# Processing Record 24 of Set 6 | piliscsaba
# Processing Record 25 of Set 6 | touros
# Processing Record 26 of Set 6 | pangnirtung
# Processing Record 27 of Set 6 | milici
# Processing Record 28 of Set 6 | vestmanna
# Processing Record 29 of Set 6 | remscheid
# Processing Record 30 of Set 6 | camacha
# Processing Record 31 of Set 6 | nome
# Processing Record 32 of Set 6 | victoria
# Processing Record 33 of Set 6 | hami
# Processing Record 34 of Set 6 | necochea
# Processing Record 35 of Set 6 | kodiak
# Processing Record 36 of Set 6 | kovdor
# Processing Record 37 of Set 6 | ardakan
# Processing Record 38 of Set 6 | richards bay
# Processing Record 39 of Set 6 | tyazhinskiy
# Processing Record 40 of Set 6 | kirakira
# Processing Record 41 of Set 6 | san rafael del sur
# Processing Record 42 of Set 6 | ewa beach
# Processing Record 43 of Set 6 | zharkent
# Processing Record 44 of Set 6 | nanyamba
# Processing Record 45 of Set 6 | zonguldak
# Processing Record 46 of Set 6 | jibou
# Processing Record 47 of Set 6 | dalhousie
# Processing Record 48 of Set 6 | bolungarvik
# City 'bolungarvik' not found. Skipping...
# Processing Record 49 of Set 6 | upata
# Processing Record 50 of Set 6 | coihaique
# Processing Record 51 of Set 6 | nongan
# Processing Record 1 of Set 7 | vaitupu
# City 'vaitupu' not found. Skipping...
# Processing Record 2 of Set 7 | dawei
# Processing Record 3 of Set 7 | villa carlos paz
# Processing Record 4 of Set 7 | lasa
# Processing Record 5 of Set 7 | armacao dos buzios
# City 'armacao dos buzios' not found. Skipping...
# Processing Record 6 of Set 7 | longyearbyen
# Processing Record 7 of Set 7 | mount gambier
# Processing Record 8 of Set 7 | rio grande
# Processing Record 9 of Set 7 | lagoa
# Processing Record 10 of Set 7 | khani
# Processing Record 11 of Set 7 | adelaide
# Processing Record 12 of Set 7 | juba
# Processing Record 13 of Set 7 | russell
# Processing Record 14 of Set 7 | willmar
# Processing Record 15 of Set 7 | sassandra
# Processing Record 16 of Set 7 | neiafu
# Processing Record 17 of Set 7 | hualmay
# Processing Record 18 of Set 7 | payson
# Processing Record 19 of Set 7 | ahuimanu
# Processing Record 20 of Set 7 | mankono
# Processing Record 21 of Set 7 | erin
# Processing Record 22 of Set 7 | muros
# Processing Record 23 of Set 7 | stephenville
# Processing Record 24 of Set 7 | bocaranga
# City 'bocaranga' not found. Skipping...
# Processing Record 25 of Set 7 | sentyabrskiy
# City 'sentyabrskiy' not found. Skipping...
# Processing Record 26 of Set 7 | dinguiraye
# Processing Record 27 of Set 7 | cam ranh
# Processing Record 48 of Set 8 | san quintin
# Processing Record 49 of Set 8 | sheridan
# Processing Record 50 of Set 8 | alyangula
# Processing Record 51 of Set 8 | ponta delgada
# Processing Record 1 of Set 9 | aksu
# Processing Record 2 of Set 9 | vanimo
# Processing Record 3 of Set 9 | ngukurr
# City 'ngukurr' not found. Skipping...
# Processing Record 4 of Set 9 | baghdad
# Processing Record 5 of Set 9 | izumo
# Processing Record 6 of Set 9 | norman wells
# Processing Record 7 of Set 9 | sao joao da barra
# Processing Record 8 of Set 9 | sioux lookout
# Processing Record 9 of Set 9 | broome
# Processing Record 10 of Set 9 | sindou
# Processing Record 11 of Set 9 | santa maria
# Processing Record 12 of Set 9 | shunyi
# Processing Record 13 of Set 9 | weston
# Processing Record 14 of Set 9 | khonuu
# City 'khonuu' not found. Skipping...
# Processing Record 15 of Set 9 | anchorage
# Processing Record 16 of Set 9 | bezhetsk
# Processing Record 17 of Set 9 | lolua
# City 'lolua' not found. Skipping...
# Processing Record 18 of Set 9 | inyonga
# Processing Record 19 of Set 9 | antofagasta
# Processing Record 20 of Set 9 | vao
# Processing Record 21 of Set 9 | seidu
# Processing Record 22 of Set 9 | olinda
# Processing Record 23 of Set 9 | port shepstone
# Processing Record 24 of Set 9 | outlook
# Processing Record 25 of Set 9 | tracy
# Processing Record 26 of Set 9 | surab
# Processing Record 27 of Set 9 | mahajanga
# Processing Record 28 of Set 9 | san isidro
# Processing Record 29 of Set 9 | qinhuangdao
# Processing Record 30 of Set 9 | preston
# Processing Record 31 of Set 9 | cayenne
# Processing Record 32 of Set 9 | vila do maio
# Processing Record 33 of Set 9 | severo-kurilsk
# Processing Record 34 of Set 9 | port hawkesbury
# Processing Record 35 of Set 9 | tafresh
# Processing Record 36 of Set 9 | sampit
# Processing Record 37 of Set 9 | warmbad
# Processing Record 38 of Set 9 | kerema
# Processing Record 39 of Set 9 | kloulklubed
# Processing Record 40 of Set 9 | tonantins
# Processing Record 41 of Set 9 | port hardy
# Processing Record 42 of Set 9 | srednekolymsk
# Processing Record 43 of Set 9 | alice springs
# Processing Record 44 of Set 9 | bengkalis
# City 'bengkalis' not found. Skipping...
# Processing Record 45 of Set 9 | tombouctou
# Processing Record 46 of Set 9 | fort dodge
# Processing Record 47 of Set 9 | chatra
# Processing Record 48 of Set 9 | ancud
# Processing Record 49 of Set 9 | zhanatas
# City 'zhanatas' not found. Skipping...
# Processing Record 50 of Set 9 | tazmalt
# Processing Record 51 of Set 9 | shache
# Processing Record 1 of Set 10 | new norfolk
# Processing Record 2 of Set 10 | udachnyy
# Processing Record 3 of Set 10 | skalistyy
# City 'skalistyy' not found. Skipping...
# Processing Record 4 of Set 10 | westport
# Processing Record 5 of Set 10 | kalmunai
# Processing Record 6 of Set 10 | bubaque
# Processing Record 7 of Set 10 | puerto escondido
# Processing Record 8 of Set 10 | cascais
# Processing Record 9 of Set 10 | christchurch
# Processing Record 10 of Set 10 | yatou
# Processing Record 11 of Set 10 | talnakh
# Processing Record 12 of Set 10 | kuytun
# Processing Record 13 of Set 10 | sabha
# Processing Record 14 of Set 10 | karratha
# Processing Record 15 of Set 10 | linjiang
# Processing Record 16 of Set 10 | villarrica
# Processing Record 17 of Set 10 | surt
# Processing Record 18 of Set 10 | sataua
# City 'sataua' not found. Skipping...
# Processing Record 19 of Set 10 | ibra
# Processing Record 20 of Set 10 | peruibe
# Processing Record 21 of Set 10 | orlik
# Processing Record 22 of Set 10 | tenenkou
# Processing Record 23 of Set 10 | padang
# Processing Record 24 of Set 10 | hudson bay
# Processing Record 25 of Set 10 | victor harbor
# Processing Record 26 of Set 10 | hearst
# Processing Record 27 of Set 10 | kumeny
# Processing Record 28 of Set 10 | north bend
# Processing Record 29 of Set 10 | hofn
# Processing Record 30 of Set 10 | mopti
# Processing Record 31 of Set 10 | yomitan
# City 'yomitan' not found. Skipping...
# Processing Record 32 of Set 10 | esso
# Processing Record 33 of Set 10 | iquitos
# Processing Record 34 of Set 10 | sorland
# Processing Record 35 of Set 10 | emba
# Processing Record 36 of Set 10 | inderborskiy
# City 'inderborskiy' not found. Skipping...
# Processing Record 37 of Set 10 | hasaki
# Processing Record 38 of Set 10 | fatehpur
# Processing Record 39 of Set 10 | shabo
# Processing Record 40 of Set 10 | imperia
# Processing Record 41 of Set 10 | teahupoo
# Processing Record 42 of Set 10 | synya
# Processing Record 43 of Set 10 | nishihara
# Processing Record 44 of Set 10 | keflavik
# Processing Record 45 of Set 10 | alekseyevsk
# Processing Record 46 of Set 10 | sar-e pul
# Processing Record 47 of Set 10 | vikhorevka
# Processing Record 48 of Set 10 | wamba
# Processing Record 49 of Set 10 | kirkwall
# Processing Record 50 of Set 10 | oranjestad
# Processing Record 51 of Set 10 | pop
# Processing Record 1 of Set 11 | eisenach
# Processing Record 2 of Set 11 | lata
# Processing Record 3 of Set 11 | pryamitsyno
# Processing Record 4 of Set 11 | tiruchchendur
# Processing Record 5 of Set 11 | vysokaya gora
# Processing Record 6 of Set 11 | achisay
# City 'achisay' not found. Skipping...
# Processing Record 7 of Set 11 | orcopampa
# Processing Record 8 of Set 11 | maragogi
# Processing Record 9 of Set 11 | olutanga
# Processing Record 10 of Set 11 | comodoro rivadavia
# Processing Record 11 of Set 11 | ulladulla
# Processing Record 12 of Set 11 | el cobre
# Processing Record 13 of Set 11 | maple creek
# Processing Record 14 of Set 11 | urusha
# Processing Record 15 of Set 11 | bhadrachalam
# Processing Record 16 of Set 11 | libreville
# Processing Record 17 of Set 11 | sabang
# Processing Record 18 of Set 11 | lianzhou
# Processing Record 19 of Set 11 | altamirano
# Processing Record 20 of Set 11 | sorvag
# City 'sorvag' not found. Skipping...
# Processing Record 21 of Set 11 | bria
# Processing Record 22 of Set 11 | taoudenni
# Processing Record 23 of Set 11 | burley
# Processing Record 24 of Set 11 | kankaanpaa
# Processing Record 25 of Set 11 | springbok
# Processing Record 26 of Set 11 | santiago
# Processing Record 27 of Set 11 | cabedelo
# Processing Record 28 of Set 11 | flin flon
# Processing Record 29 of Set 11 | luwuk
# Processing Record 30 of Set 11 | conde
# Processing Record 31 of Set 11 | matara
# Processing Record 32 of Set 11 | zhanaozen
# Processing Record 33 of Set 11 | te anau
# Processing Record 34 of Set 11 | sofiyivka
# Processing Record 35 of Set 11 | indianola
# Processing Record 36 of Set 11 | fuzhou
# Processing Record 37 of Set 11 | granada
# Processing Record 38 of Set 11 | mezen
# Processing Record 39 of Set 11 | tiksi
# Processing Record 40 of Set 11 | kollumerland
# City 'kollumerland' not found. Skipping...
# Processing Record 41 of Set 11 | diffa
# Processing Record 42 of Set 11 | port antonio
# Processing Record 43 of Set 11 | upington
# Processing Record 44 of Set 11 | catuday
# Processing Record 45 of Set 11 | celestun
# Processing Record 46 of Set 11 | locri
# Processing Record 47 of Set 11 | ardesen
# Processing Record 48 of Set 11 | kidal
# Processing Record 49 of Set 11 | praia da vitoria
# Processing Record 50 of Set 11 | shirokiy
# Processing Record 51 of Set 11 | malente
# Processing Record 1 of Set 12 | susangerd
# Processing Record 2 of Set 12 | batagay-alyta
# Processing Record 3 of Set 12 | timberlake
# Processing Record 4 of Set 12 | phangnga
# Processing Record 5 of Set 12 | yambio
# Processing Record 6 of Set 12 | wajir
# Processing Record 7 of Set 12 | tir pol
# City 'tir pol' not found. Skipping...
# Processing Record 8 of Set 12 | andalan
# Processing Record 9 of Set 12 | pemangkat
# Processing Record 10 of Set 12 | skagastrond
# City 'skagastrond' not found. Skipping...
# Processing Record 11 of Set 12 | longonjo
# Processing Record 12 of Set 12 | pisco
# Processing Record 13 of Set 12 | la palma
# Processing Record 14 of Set 12 | taltal
# Processing Record 15 of Set 12 | tukrah
# Processing Record 16 of Set 12 | aykhal
# Processing Record 17 of Set 12 | san ramon
# Processing Record 18 of Set 12 | venice
# Processing Record 19 of Set 12 | zaysan
# Processing Record 20 of Set 12 | razdolinsk
# Processing Record 21 of Set 12 | plettenberg bay
# Processing Record 22 of Set 12 | mahina
# Processing Record 23 of Set 12 | bar harbor
# Processing Record 24 of Set 12 | ust-ilimsk
# Processing Record 25 of Set 12 | hambantota
# Processing Record 26 of Set 12 | tibiao
# Processing Record 27 of Set 12 | garchitorena
# Processing Record 28 of Set 12 | salamiyah
# Processing Record 29 of Set 12 | marzuq
# Processing Record 30 of Set 12 | havelock
# Processing Record 31 of Set 12 | sambava
# Processing Record 32 of Set 12 | zhangye
# Processing Record 33 of Set 12 | duki
# Processing Record 34 of Set 12 | sinnamary
# Processing Record 35 of Set 12 | berdigestyakh
# Processing Record 36 of Set 12 | belmonte
# Processing Record 37 of Set 12 | diapaga
# Processing Record 38 of Set 12 | maceio
# Processing Record 39 of Set 12 | bilma
# Processing Record 40 of Set 12 | da nang
# Processing Record 41 of Set 12 | camana
# Processing Record 42 of Set 12 | roma
# Processing Record 43 of Set 12 | merauke
# Processing Record 44 of Set 12 | zafra
# Processing Record 45 of Set 12 | marrakesh
# Processing Record 46 of Set 12 | emerald
# Processing Record 47 of Set 12 | bargal
# City 'bargal' not found. Skipping...
# Processing Record 48 of Set 12 | muroto
# Processing Record 49 of Set 12 | sibolga
# Processing Record 50 of Set 12 | hihya
# Processing Record 51 of Set 12 | ketchikan
# Processing Record 1 of Set 13 | camocim
# Processing Record 2 of Set 13 | krutinka
# Processing Record 3 of Set 13 | mamlyutka
# Processing Record 4 of Set 13 | chuy
# Processing Record 5 of Set 13 | buin
# Processing Record 6 of Set 13 | litoral del san juan
# City 'litoral del san juan' not found. Skipping...
# Processing Record 7 of Set 13 | bima
# Processing Record 8 of Set 13 | guanambi
# Processing Record 9 of Set 13 | portland
# Processing Record 10 of Set 13 | poum
# Processing Record 11 of Set 13 | solnechnyy
# Processing Record 12 of Set 13 | daru
# Processing Record 13 of Set 13 | bethel
# Processing Record 14 of Set 13 | galesong
# Processing Record 15 of Set 13 | langxiang
# Processing Record 16 of Set 13 | kota belud
# Processing Record 17 of Set 13 | thunder bay
# Processing Record 18 of Set 13 | kholodnyy
# Processing Record 19 of Set 13 | wanaka
# Processing Record 20 of Set 13 | bowen
# Processing Record 21 of Set 13 | serov
# Processing Record 22 of Set 13 | amparai
# City 'amparai' not found. Skipping...
# Processing Record 23 of Set 13 | mantua
# Processing Record 24 of Set 13 | karasuk
# Processing Record 25 of Set 13 | halalo
# City 'halalo' not found. Skipping...
# Processing Record 26 of Set 13 | revelstoke
# Processing Record 27 of Set 13 | inhambane
# Processing Record 28 of Set 13 | joanopolis
# Processing Record 29 of Set 13 | fallon
# Processing Record 30 of Set 13 | nueva loja
# Processing Record 31 of Set 13 | rafraf
# ------------------------------
# Data Retrieval Complete.
# Processed 583 number of cities.
# 48 cities not found.
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data = pd.DataFrame({
    "City": cities_with_data,
    "Lat": lat,
    "Lng": lon,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
})
city_data.head()
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Philippe -21.3585  55.7679    294.94        82          76
# 1    Punta Arenas -53.1500 -70.9167    275.21        75          20
# 2          Albany  42.6001 -73.9662    305.05        50          29
# 3      Porto-Novo   6.4965   2.6036    302.05        61          91
# 4          Dikson  73.5069  80.5464    280.26        84         100
#
#    Wind Speed Country        Date
# 0        4.44      RE  1658674707
# 1        6.17      CL  1658674707
# 2        0.45      US  1658674679
# 3        4.47      BJ  1658674707
# 4        7.24      RU  1658674708

# %%
city_data.to_csv(output_data_file, encoding='utf-8')

# %%
city_stats = city_data.agg(['count', 'mean', 'std', 'min', 'max'])[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']]
city_stats_2 = city_data[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']].quantile([.25, .5, .75])
city_stats = pd.concat([city_stats, city_stats_2])
city_stats.set_axis(['count', 'mean', 'std', 'min', 'max', '25%', '50%', '75%'], axis='index', inplace=True)
city_stats
# Out:
# C:\Users\aimee\AppData\Local\Temp\ipykernel_20048\4033170135.py:1: FutureWarning: ['City', 'Country'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   city_stats = city_data.agg(['count', 'mean', 'std', 'min', 'max'])[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']]
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  583.000000  583.000000  583.000000  583.000000  583.000000  583.000000
# mean    19.629421   14.852813  295.612847   68.833619   55.204117    3.503705
# std     32.649915   91.368812    8.277460   22.123011   39.025076    2.321887
# min    -54.800000 -175.200000  271.900000    5.000000    0.000000    0.000000
# max     78.218600  178.416700  318.560000  100.000000  100.000000   14.500000
# 25%     -6.932750  -68.407250  289.850000   58.000000   15.500000    1.650000
# 50%     21.346900   19.234500  297.150000   75.000000   63.000000    3.000000
# 75%     46.121300   98.364900  301.105000   84.500000   97.500000    4.990000
#
#                Date
# count  5.830000e+02
# mean   1.658675e+09
# std    1.019988e+02
# min    1.658674e+09
# max    1.658675e+09
# 25%    1.658675e+09
# 50%    1.658675e+09
# 75%    1.658675e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.

# %%
clean_city_data = city_data[city_data['Humidity'] <= 100]

clean_city_stats = clean_city_data.agg(['count', 'mean', 'std', 'min', 'max'])[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']]
clean_city_stats_2 = clean_city_data[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']].quantile([.25, .5, .75])
clean_city_stats = pd.concat([clean_city_stats, clean_city_stats_2])
clean_city_stats.set_axis(['count', 'mean', 'std', 'min', 'max', '25%', '50%', '75%'], axis='index', inplace=True)
clean_city_stats
# Out:
# C:\Users\aimee\AppData\Local\Temp\ipykernel_20048\1174230322.py:1: FutureWarning: ['City', 'Country'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   clean_city_stats = clean_city_data.agg(['count', 'mean', 'std', 'min', 'max'])[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']]
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  580.000000  580.000000  580.000000  580.000000  580.000000  580.000000
# mean    19.639713   14.572643  295.675828   68.672414   55.112069    3.509776
# std     32.584427   90.990780    8.249256   22.065915   39.008252    2.322159
# min    -54.800000 -175.200000  271.900000    5.000000    0.000000    0.000000
# max     78.218600  178.416700  318.560000   99.000000  100.000000   14.500000
# 25%     -6.908575  -68.353625  289.950000   58.000000   15.000000    1.657500
# 50%     21.331250   19.162400  297.180000   75.000000   62.500000    3.005000
# 75%     46.115650   97.692100  301.115000   84.000000   97.000000    4.985000
#
#                Date
# count  5.800000e+02
# mean   1.658675e+09
# std    1.021823e+02
# min    1.658674e+09
# max    1.658675e+09
# 25%    1.658675e+09
# 50%    1.658675e+09
# 75%    1.658675e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# City Latitude vs Max Temperature (07/24/2022)
plt.scatter(clean_city_data['Lat'], clean_city_data['Max Temp'], marker="o", edgecolors='black')
plt.title("City Latitude vs. Max Temperature (07/24/2022)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

plt.savefig("Images/CityLatitudeVsMaxTemp.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# City Latitude vs Humidity (07/24/2022)
plt.scatter(clean_city_data['Lat'], clean_city_data['Humidity'], marker="o", edgecolors='black')
plt.title("City Latitude vs. Humidity (07/24/2022)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

plt.savefig("Images/CityLatitudeVsHumidity.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# City Latitude vs Cloudiness (07/24/2022)
plt.scatter(clean_city_data['Lat'], clean_city_data['Cloudiness'], marker="o", edgecolors='black')
plt.title("City Latitude vs. Cloudiness (07/24/2022)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

plt.savefig("Images/CityLatitudeVsCloudiness.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# City Latitude vs Wind Speed (07/24/2022)
plt.scatter(clean_city_data['Lat'], clean_city_data['Wind Speed'], marker="o", edgecolors='black')
plt.title("City Latitude vs. Wind Speed (07/24/2022)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

plt.savefig("Images/CityLatitudeVsWindSpeed.png")

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Negative latitudes = southern hemisphere
# clean_city_data = city_data[city_data['Humidity'] < 100]
south_hemi = clean_city_data[clean_city_data['Lat'] < 0]
north_hemi = clean_city_data[clean_city_data['Lat'] > 0]
print(f"# Northern Hemisphere Cities: {len(north_hemi)}.\n# Southern Hemisphere Cities: {len(south_hemi)}.")
# Out:
# # Northern Hemisphere Cities: 404.
# # Southern Hemisphere Cities: 176.

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
xValues = north_hemi['Lat']
yValues = north_hemi['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yValues)
regress_values = xValues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xValues,yValues)
plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq, (10,275), fontsize=15, color="red")
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression (07/24/2022)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

plt.savefig("Images/NorthHemiCityLatitudeVsMaxTempRegress.png")

plt.show()

print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: -0.6270709222687066

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
xValues = south_hemi['Lat']
yValues = south_hemi['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yValues)
regress_values = xValues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xValues,yValues)
plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq, (-30,275), fontsize=15, color="red")
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression (07/24/2022)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

plt.savefig("Images/SouthHemiCityLatitudeVsMaxTempRegress.png")

plt.show()

print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.8193517269419254

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xValues = north_hemi['Lat']
yValues = north_hemi['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yValues)
regress_values = xValues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xValues,yValues)
plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq, (50,10), fontsize=13, color="red")
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression (07/24/2022)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig("Images/NorthHemiCityLatitudeVsHumidityRegress.png")

plt.show()

print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.07839922073454107

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xValues = south_hemi['Lat']
yValues = south_hemi['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yValues)
regress_values = xValues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xValues,yValues)
plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq, (-53,30), fontsize=15, color="red")
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression (07/24/2022)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig("Images/SouthHemiCityLatitudeVsHumidityRegress.png")

plt.show()

print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: -0.161757975065061

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xValues = north_hemi['Lat']
yValues = north_hemi['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yValues)
regress_values = xValues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xValues,yValues)
plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq, (40,10), fontsize=15, color="red")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression (07/24/2022)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig("Images/NorthHemiCityLatitudeVsCloudinessRegress.png")

plt.show()

print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: -0.02907603869150067

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xValues = south_hemi['Lat']
yValues = south_hemi['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yValues)
regress_values = xValues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xValues,yValues)
plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq, (-53,30), fontsize=15, color="red")
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression (07/24/2022)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig("Images/SouthHemiCityLatitudeVsCloudinessRegress.png")

plt.show()

print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.04328710842702335

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xValues = north_hemi['Lat']
yValues = north_hemi['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yValues)
regress_values = xValues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xValues,yValues)
plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq, (20,12), fontsize=15, color="red")
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression (07/24/2022)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig("Images/NorthHemiCityLatitudeVsWindSpeedRegress.png")

plt.show()

print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: -0.006321975614337564

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xValues = south_hemi['Lat']
yValues = south_hemi['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yValues)
regress_values = xValues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(xValues,yValues)
plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq, (-53,10), fontsize=15, color="red")
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression (07/24/2022)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig("Images/SouthHemiCityLatitudeVsWindSpeedRegress.png")

plt.show()

print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.022387457037035468
